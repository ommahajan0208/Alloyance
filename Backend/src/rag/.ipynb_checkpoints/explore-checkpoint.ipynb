# %%
# import pypdf
# print("pypdf version:", pypdf.__version__)

# import sys
# !{sys.executable} -m pip install tf-keras
# Out:
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.3.1-py3-none-any.whl.metadata (996 bytes)
# Collecting langchain-chroma
#   Downloading langchain_chroma-0.2.6-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.70 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-huggingface) (0.3.76)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-huggingface) (0.22.1)
# Requirement already satisfied: huggingface-hub>=0.33.4 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-huggingface) (0.35.1)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.4.30)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (4.12.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (24.2)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.10.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ommah\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.1)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-chroma) (2.1.3)
# Requirement already satisfied: chromadb>=1.0.20 in c:\users\ommah\anaconda3\lib\site-packages (from langchain-chroma) (1.1.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\ommah\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (0.37.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.37.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (3.11.3)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\ommah\anaconda3\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (4.23.0)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\ommah\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\ommah\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\ommah\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\ommah\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\ommah\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ommah\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ommah\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ommah\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ommah\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2025.4.26)
# Requirement already satisfied: pyproject_hooks in c:\users\ommah\anaconda3\lib\site-packages (from build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\users\ommah\anaconda3\lib\site-packages (from build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (0.4.6)
# Requirement already satisfied: anyio in c:\users\ommah\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ommah\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ommah\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (0.16.0)
# Requirement already satisfied: filelock in c:\users\ommah\anaconda3\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ommah\anaconda3\lib\site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (2025.3.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ommah\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ommah\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ommah\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ommah\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (0.22.3)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\ommah\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\ommah\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\ommah\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\ommah\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\ommah\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ommah\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ommah\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ommah\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\ommah\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.4.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ommah\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ommah\anaconda3\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ommah\anaconda3\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\ommah\anaconda3\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.27.1)
# Requirement already satisfied: coloredlogs in c:\users\ommah\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\ommah\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\ommah\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (5.29.3)
# Requirement already satisfied: sympy in c:\users\ommah\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\ommah\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.20->langchain-chroma) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\ommah\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=1.0.20->langchain-chroma) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\ommah\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\ommah\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\ommah\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\ommah\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb>=1.0.20->langchain-chroma) (0.58b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ommah\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ommah\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ommah\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (0.1.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ommah\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb>=1.0.20->langchain-chroma) (8.1.8)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\ommah\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\ommah\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (1.1.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\ommah\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\ommah\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ommah\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\ommah\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\ommah\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (3.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ommah\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (1.3.0)
# Downloading langchain_huggingface-0.3.1-py3-none-any.whl (27 kB)
# Downloading langchain_chroma-0.2.6-py3-none-any.whl (12 kB)
# Installing collected packages: langchain-huggingface, langchain-chroma
#
#    ---------------------------------------- 2/2 [langchain-chroma]
#
# Successfully installed langchain-chroma-0.2.6 langchain-huggingface-0.3.1

# %%
from langchain.document_loaders import DirectoryLoader
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings  # <-- NEW

import os
import shutil
import glob

# Using local embeddings instead of OpenAI paid api
CHROMA_PATH = "chroma"
DATA_PATH = os.path.join("..", "..", "data", "rag_data")

def main():
    generate_data_store()

def generate_data_store():
    documents = load_documents()
    chunks = split_text(documents)
    save_to_chroma(chunks)

def load_documents():
    documents = []
    pdf_files = glob.glob(os.path.join(DATA_PATH, "*.pdf"))  # Load all PDFs
    for file_path in pdf_files:
        loader = PyPDFLoader(file_path)
        documents.extend(loader.load())
    print(f"Loaded {len(documents)} pages from {len(pdf_files)} PDF files.")
    return documents

def split_text(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=300,
        chunk_overlap=100,
        length_function=len,
        add_start_index=True,
    )
    chunks = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(chunks)} chunks.")
    return chunks

def save_to_chroma(chunks: list[Document]):
    # Clear out the database first, but safely
    if os.path.exists(CHROMA_PATH):
        try:
            shutil.rmtree(CHROMA_PATH)
        except PermissionError:
            print("Chroma DB is locked or used by other kernel")
            return

    # Use free, local embedding model
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

    # Create a new DB from the documents
    db = Chroma.from_documents(chunks, embeddings, persist_directory=CHROMA_PATH)
    db.persist()
    db = None  # Explicitly drop reference to release file handles
    print(f" Saved {len(chunks)} chunks to {CHROMA_PATH}.")


if __name__ == "__main__":
    main()
# Out:
# Loaded 13 pages from 1 PDF files.
# Split 13 documents into 290 chunks.
# C:\Users\ommah\AppData\Local\Temp\ipykernel_16868\1407763816.py:54: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# WARNING:tensorflow:From C:\Users\ommah\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
#  Saved 290 chunks to chroma.
# C:\Users\ommah\AppData\Local\Temp\ipykernel_16868\1407763816.py:58: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   db.persist()

# %%
import argparse
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.llms import HuggingFaceHub  # free model from HuggingFace Hub

CHROMA_PATH = "chroma"

PROMPT_TEMPLATE = """
Answer the question based only on the following context:

{context}

---

Answer the question based on the above context: {question}
"""

def main():
    # CLI for passing question
    parser = argparse.ArgumentParser()
    parser.add_argument("query_text", type=str, help="The query text you want to ask.")
    args = parser.parse_args()
    query_text = args.query_text

    # Prepare the DB with local embeddings
    embedding_function = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    db = Chroma(persist_directory=CHROMA_PATH, embedding_function=embedding_function)

    # Search the DB (top 3 chunks)
    results = db.similarity_search_with_relevance_scores(query_text, k=3)
    if len(results) == 0 or results[0][1] < 0.3:
        print(f"Unable to find good matching results.")
        return

    # Prepare the context for the prompt
    context_text = "\n\n---\n\n".join([doc.page_content for doc, _ in results])
    prompt = PromptTemplate.from_template(PROMPT_TEMPLATE)
    final_prompt = prompt.format(context=context_text, question=query_text)

    # Load a free HuggingFace LLM (e.g. flan-t5-base)
    llm = HuggingFaceHub(repo_id="google/flan-t5-base", model_kwargs={"temperature": 0, "max_length": 512})
    chain = LLMChain(llm=llm, prompt=prompt)

    response_text = chain.run({"context": context_text, "question": query_text})

    # Print results
    sources = [doc.metadata.get("source", None) for doc, _ in results]
    formatted_response = f"Response: {response_text}\n\nSources: {sources}"
    print(formatted_response)

if __name__ == "__main__":
    main()
# Out:
# usage: ipykernel_launcher.py [-h] query_text
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\ommah\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
